# %% [markdown]
# Following the installation of Google Colab, we'll look to perform a few tests.

# %%
# This is a simple Python script that prints the number 1 to the console
print(1)
# Out:
# 1

# %%
# The following code is a JavaScript (not Python)snippet that declares a variable and attempts to print it, but it contains an error due to case sensitivity
let studentName = "Aisha"
console.log(StudentName)
# Out:
#   File "/tmp/ipykernel_10443/4148049949.py", line 1
#     let studentName = "Aisha"
#         ^
# SyntaxError: invalid syntax

# %%
# The corrected Python code to declare a variable and print it would be:
student_name = "Aisha"
print(student_name)
# Out:
# Aisha

# %% [markdown]
# Now we'll look to assign mutiple variables with different values and print these for analysis.

# %%
student_name = "Aisha"
age = 21
course = "Python and Machine Learning"

print(student_name)
print(age)
print(course)
# Out:
# Aisha
# 21
# Python and Machine Learning
